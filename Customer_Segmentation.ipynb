# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-91e89e4b520c> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib seaborn scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-91e89e4b520c> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat import (
#      23     np_version_under1p18 as _np_version_under1p18,
#      24     is_numpy_dev as _is_numpy_dev,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\compat\__init__.py in <module>
#      13
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_array_datetime64_compat,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\compat\numpy\__init__.py in <module>
# ...

# %%
# !pip uninstall numpy pandas -y
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\cli\base_command.py", line 167, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\commands\uninstall.py", line 102, in run
#     uninstall_pathset.commit()
#   File "C:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\req\req_uninstall.py", line 420, in commit
#     self._moved_paths.commit()
#   File "C:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\req\req_uninstall.py", line 273, in commit
#     save_dir.cleanup()
#   File "C:\Users\LENOVO\AppData\Local\Programs\Python\Python39\lib\site-packages\pip\_internal\utils\temp_dir.py", line 173, in cleanup
#     rmtree(self._path)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-9d745fdca97a> in <module>
#       3 for i in range(1, 11):
#       4     kmeans = KMeans(n_clusters=i, random_state=42)
# ----> 5     kmeans.fit(X_scaled)
#       6     wcss.append(kmeans.inertia_)
#       7
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1006         if self._algorithm == "full":
#    1007             kmeans_single = _kmeans_single_lloyd
# -> 1008             self._check_mkl_vcomp(X, X.shape[0])
#    1009         else:
#    1010             kmeans_single = _kmeans_single_elkan
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py in _check_mkl_vcomp(self, X, n_samples)
#     872         active_threads = int(np.ceil(n_samples / CHUNK_SIZE))
# ...

# %%
# !pip install --upgrade threadpoolctl scikit-learn
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\LENOVO\\AppData\\Local\\Programs\\Python\\Python39\\Lib\\site-packages\\~klearn\\.libs\\vcomp140.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 22.0.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'C:\Users\LENOVO\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#   Using cached scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.1.0
#     Uninstalling threadpoolctl-2.1.0:
#       Successfully uninstalled threadpoolctl-2.1.0
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
# ...

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9d745fdca97a> in <module>
#       3 for i in range(1, 11):
#       4     kmeans = KMeans(n_clusters=i, random_state=42)
# ----> 5     kmeans.fit(X_scaled)
#       6     wcss.append(kmeans.inertia_)
#       7
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1006         if init_size is not None and init_size < n_samples:
#    1007             init_indices = random_state.randint(0, n_samples, init_size)
# -> 1008             X = X[init_indices]
#    1009             x_squared_norms = x_squared_norms[init_indices]
#    1010             n_samples = X.shape[0]
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py in _check_mkl_vcomp(self, X, n_samples)
# ...

# %%
# !pip install --force-reinstall scikit-learn==1.2.2 threadpoolctl==3.1.0

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9d745fdca97a> in <module>
#       2
#       3 for i in range(1, 11):
# ----> 4     kmeans = KMeans(n_clusters=i, random_state=42)
#       5     kmeans.fit(X_scaled)
#       6     wcss.append(kmeans.inertia_)
#
# NameError: name 'KMeans' is not defined

# %%
kmeans.fit(X_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8a1f7c7d593a> in <module>
# ----> 1 kmeans.fit(X_scaled)
#
# NameError: name 'kmeans' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9d745fdca97a> in <module>
#       3 for i in range(1, 11):
#       4     kmeans = KMeans(n_clusters=i, random_state=42)
# ----> 5     kmeans.fit(X_scaled)
#       6     wcss.append(kmeans.inertia_)
#       7
#
# NameError: name 'X_scaled' is not defined

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1aeb2146bc97> in <module>
# ----> 1 X = df[['Annual Income (k$)', 'Spending Score (1-100)']]
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
y_kmeans = kmeans.fit_predict(X_scaled)

df['Cluster'] = y_kmeans

# %%
plt.figure(figsize=(8,6))

for i in range(5):
    plt.scatter(X_scaled[y_kmeans == i, 0],
                X_scaled[y_kmeans == i, 1],
                label=f'Cluster {i}')

plt.scatter(kmeans.cluster_centers_[:, 0],
            kmeans.cluster_centers_[:, 1],
            s=200, c='black', label='Centroids')

plt.legend()
plt.title("Customer Segmentation")
plt.show()

# %%
df.groupby('Cluster').mean()
# Out:
# <ipython-input-9-9780075f7ef4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Cluster').mean()
#          CustomerID        Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0         86.320988  42.716049           55.296296               49.518519
# 1        162.000000  32.692308           86.538462               82.128205
# 2         23.090909  25.272727           25.727273               79.363636
# 3        164.371429  41.114286           88.200000               17.114286
# 4         23.000000  45.217391           26.304348               20.913043

# %%
X = df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']]

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(X_scaled, y_kmeans)
print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.5546571631111091

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
import pickle

pickle.dump(kmeans, open("model.pkl", "wb"))

# %% [markdown]
# Cluster Insights:
#
# Cluster 0: Low income, low spending customers
# Cluster 1: High income, high spending customers (VIP)
# Cluster 2: High income, low spending (target group)
# Cluster 3: Low income, high spending (impulsive buyers)
# Cluster 4: Average customers

# %% [markdown]
# Conclusion:
#
# K-Means clustering was successfully implemented to segment customers based on income and spending behavior. The model identified different customer groups which can help businesses improve marketing strategies and decision-making.
